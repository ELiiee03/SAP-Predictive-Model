# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import io

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import pickle

# %%
file = r'C:\Users\franf\Documents\4TH YEAR\IS107\csv\final_dataset.csv'  
dataset = pd.read_csv(file)
dataset
# Out:
#        no.                      name philhealth_status  ip  gender  age  \
# 0        1             BETE, RHEA M.         DEPENDENT  NO  FEMALE   20
# 1        2  DARUNDAY, CARL KEVEEN G.         DEPENDENT  NO    MALE   21
# 2        3      ABID, DOGENIO JR. A.         DEPENDENT  NO    MALE   22
# 3        4        DARAY, JOHN LOU N.         DEPENDENT  NO    MALE   20
# 4        5           ABID, EUGENE A.         DEPENDENT  NO    MALE   26
# ...    ...                       ...               ...  ..     ...  ...
# 1188  1189  GETUBIG, IAN CHRISGERENE            MEMBER  NO  FEMALE   20
# 1189  1190    BOLAMBOT, MELISSA JANE       INDEPENDENT  NO  FEMALE   26
# 1190  1191  FELICILDA, CHRISTIAN JAY            MEMBER  NO    MALE   26
# 1191  1192        BOLAMBOT, JHOMARIE              NONE  NO    MALE   28
# 1192  1193        BOLAMBOT, JOHN MAR       INDEPENDENT  NO    MALE   29
#
#      civil_status  number_of_children highest_education_attainment osy_isy  \
# 0          SINGLE                   0                COLLEGE LEVEL      IN
# 1          SINGLE                   0                COLLEGE LEVEL      IN
# 2          SINGLE                   0                   VOCATIONAL      IN
# 3          SINGLE                   0                COLLEGE LEVEL      IN
# 4          SINGLE                   0             COLLEGE GRADUATE    NONE
# ...           ...                 ...                          ...     ...
# 1188       SINGLE                   0                      COLLEGE      IN
# 1189       SINGLE                   0                      COLLEGE     OUT
# 1190       SINGLE                   0                      COLLEGE     OUT
# 1191      LIVE IN                   0                      COLLEGE     OUT
# 1192      LIVE IN                   0                 HIGH SCHOOL      OUT
#
#                     out youth_with_specific_needs disability work_status  \
# 0                  NONE                        NO       NONE    EMPLOYED
# 1                  NONE                        NO       NONE  UNEMPLOYED
# 2                  NONE                        NO       NONE  UNEMPLOYED
# 3                  NONE                        NO       NONE    EMPLOYED
# 4                  NONE                        NO       NONE  UNEMPLOYED
# ...                 ...                       ...        ...         ...
# 1188               NONE                        NO       NONE  UNEMPLOYED
# 1189               NONE                        NO       NONE    EMPLOYED
# 1190               NONE                        NO       NONE    EMPLOYED
# 1191               NONE                        NO       NONE    EMPLOYED
# 1192  FINANCIAL PROBLEM                        NO       NONE    EMPLOYED
#
#      priority_level
# 0      NOT PRIORITY
# 1      NOT PRIORITY
# 2      NOT PRIORITY
# 3      NOT PRIORITY
# 4      NOT PRIORITY
# ...             ...
# 1188   NOT PRIORITY
# 1189   NOT PRIORITY
# 1190   NOT PRIORITY
# 1191   NOT PRIORITY
# 1192   NOT PRIORITY
#
# [1193 rows x 15 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1193 entries, 0 to 1192
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   no.                           1193 non-null   int64
#  1   name                          1193 non-null   object
#  2   philhealth_status             1193 non-null   object
#  3   ip                            1193 non-null   object
#  4   gender                        1193 non-null   object
#  5   age                           1193 non-null   int64
#  6   civil_status                  1193 non-null   object
#  7   number_of_children            1193 non-null   int64
#  8   highest_education_attainment  1193 non-null   object
#  9   osy_isy                       1192 non-null   object
#  10  out                           1193 non-null   object
#  11  youth_with_specific_needs     1193 non-null   object
#  12  disability                    1193 non-null   object
#  13  work_status                   1193 non-null   object
#  14  priority_level                1193 non-null   object
# dtypes: int64(3), object(12)
# memory usage: 139.9+ KB

# %%
dataset.dropna()
# Out:
#        no.                      name philhealth_status  ip  gender  age  \
# 0        1             BETE, RHEA M.         DEPENDENT  NO  FEMALE   20
# 1        2  DARUNDAY, CARL KEVEEN G.         DEPENDENT  NO    MALE   21
# 2        3      ABID, DOGENIO JR. A.         DEPENDENT  NO    MALE   22
# 3        4        DARAY, JOHN LOU N.         DEPENDENT  NO    MALE   20
# 4        5           ABID, EUGENE A.         DEPENDENT  NO    MALE   26
# ...    ...                       ...               ...  ..     ...  ...
# 1188  1189  GETUBIG, IAN CHRISGERENE            MEMBER  NO  FEMALE   20
# 1189  1190    BOLAMBOT, MELISSA JANE       INDEPENDENT  NO  FEMALE   26
# 1190  1191  FELICILDA, CHRISTIAN JAY            MEMBER  NO    MALE   26
# 1191  1192        BOLAMBOT, JHOMARIE              NONE  NO    MALE   28
# 1192  1193        BOLAMBOT, JOHN MAR       INDEPENDENT  NO    MALE   29
#
#      civil_status  number_of_children highest_education_attainment osy_isy  \
# 0          SINGLE                   0                COLLEGE LEVEL      IN
# 1          SINGLE                   0                COLLEGE LEVEL      IN
# 2          SINGLE                   0                   VOCATIONAL      IN
# 3          SINGLE                   0                COLLEGE LEVEL      IN
# 4          SINGLE                   0             COLLEGE GRADUATE    NONE
# ...           ...                 ...                          ...     ...
# 1188       SINGLE                   0                      COLLEGE      IN
# 1189       SINGLE                   0                      COLLEGE     OUT
# 1190       SINGLE                   0                      COLLEGE     OUT
# 1191      LIVE IN                   0                      COLLEGE     OUT
# 1192      LIVE IN                   0                 HIGH SCHOOL      OUT
#
#                     out youth_with_specific_needs disability work_status  \
# 0                  NONE                        NO       NONE    EMPLOYED
# 1                  NONE                        NO       NONE  UNEMPLOYED
# 2                  NONE                        NO       NONE  UNEMPLOYED
# 3                  NONE                        NO       NONE    EMPLOYED
# 4                  NONE                        NO       NONE  UNEMPLOYED
# ...                 ...                       ...        ...         ...
# 1188               NONE                        NO       NONE  UNEMPLOYED
# 1189               NONE                        NO       NONE    EMPLOYED
# 1190               NONE                        NO       NONE    EMPLOYED
# 1191               NONE                        NO       NONE    EMPLOYED
# 1192  FINANCIAL PROBLEM                        NO       NONE    EMPLOYED
#
#      priority_level
# 0      NOT PRIORITY
# 1      NOT PRIORITY
# 2      NOT PRIORITY
# 3      NOT PRIORITY
# 4      NOT PRIORITY
# ...             ...
# 1188   NOT PRIORITY
# 1189   NOT PRIORITY
# 1190   NOT PRIORITY
# 1191   NOT PRIORITY
# 1192   NOT PRIORITY
#
# [1192 rows x 15 columns]

# %%
dataset
# Out:
#        no.                      name philhealth_status  ip  gender  age  \
# 0        1             BETE, RHEA M.         DEPENDENT  NO  FEMALE   20
# 1        2  DARUNDAY, CARL KEVEEN G.         DEPENDENT  NO    MALE   21
# 2        3      ABID, DOGENIO JR. A.         DEPENDENT  NO    MALE   22
# 3        4        DARAY, JOHN LOU N.         DEPENDENT  NO    MALE   20
# 4        5           ABID, EUGENE A.         DEPENDENT  NO    MALE   26
# ...    ...                       ...               ...  ..     ...  ...
# 1188  1189  GETUBIG, IAN CHRISGERENE            MEMBER  NO  FEMALE   20
# 1189  1190    BOLAMBOT, MELISSA JANE       INDEPENDENT  NO  FEMALE   26
# 1190  1191  FELICILDA, CHRISTIAN JAY            MEMBER  NO    MALE   26
# 1191  1192        BOLAMBOT, JHOMARIE              NONE  NO    MALE   28
# 1192  1193        BOLAMBOT, JOHN MAR       INDEPENDENT  NO    MALE   29
#
#      civil_status  number_of_children highest_education_attainment osy_isy  \
# 0          SINGLE                   0                COLLEGE LEVEL      IN
# 1          SINGLE                   0                COLLEGE LEVEL      IN
# 2          SINGLE                   0                   VOCATIONAL      IN
# 3          SINGLE                   0                COLLEGE LEVEL      IN
# 4          SINGLE                   0             COLLEGE GRADUATE    NONE
# ...           ...                 ...                          ...     ...
# 1188       SINGLE                   0                      COLLEGE      IN
# 1189       SINGLE                   0                      COLLEGE     OUT
# 1190       SINGLE                   0                      COLLEGE     OUT
# 1191      LIVE IN                   0                      COLLEGE     OUT
# 1192      LIVE IN                   0                 HIGH SCHOOL      OUT
#
#                     out youth_with_specific_needs disability work_status  \
# 0                  NONE                        NO       NONE    EMPLOYED
# 1                  NONE                        NO       NONE  UNEMPLOYED
# 2                  NONE                        NO       NONE  UNEMPLOYED
# 3                  NONE                        NO       NONE    EMPLOYED
# 4                  NONE                        NO       NONE  UNEMPLOYED
# ...                 ...                       ...        ...         ...
# 1188               NONE                        NO       NONE  UNEMPLOYED
# 1189               NONE                        NO       NONE    EMPLOYED
# 1190               NONE                        NO       NONE    EMPLOYED
# 1191               NONE                        NO       NONE    EMPLOYED
# 1192  FINANCIAL PROBLEM                        NO       NONE    EMPLOYED
#
#      priority_level
# 0      NOT PRIORITY
# 1      NOT PRIORITY
# 2      NOT PRIORITY
# 3      NOT PRIORITY
# 4      NOT PRIORITY
# ...             ...
# 1188   NOT PRIORITY
# 1189   NOT PRIORITY
# 1190   NOT PRIORITY
# 1191   NOT PRIORITY
# 1192   NOT PRIORITY
#
# [1193 rows x 15 columns]

# %%
# select features and the class label
X = dataset[['philhealth_status', 'ip', 'gender', 'age', 'civil_status', 'number_of_children' , 'highest_education_attainment', 'osy_isy', 'out', 'youth_with_specific_needs', 'disability', 'work_status']]
y = dataset['priority_level']

# %%
X['philhealth_status'] = LabelEncoder().fit_transform(X['philhealth_status'])
X['ip'] = LabelEncoder().fit_transform(X['ip'])
X['gender'] = LabelEncoder().fit_transform(X['gender'])
X['civil_status'] = LabelEncoder().fit_transform(X['civil_status'])
X['highest_education_attainment'] = LabelEncoder().fit_transform(X['highest_education_attainment'])
X['osy_isy'] = LabelEncoder().fit_transform(X['osy_isy'])
X['out'] = LabelEncoder().fit_transform(X['out'])
X['youth_with_specific_needs'] = LabelEncoder().fit_transform(X['youth_with_specific_needs'])
X['disability'] = LabelEncoder().fit_transform(X['disability'])
X['work_status'] = LabelEncoder().fit_transform(X['work_status'])
# Out:
# C:\Users\franf\AppData\Local\Temp\ipykernel_25804\3227243978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['philhealth_status'] = LabelEncoder().fit_transform(X['philhealth_status'])
# C:\Users\franf\AppData\Local\Temp\ipykernel_25804\3227243978.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['ip'] = LabelEncoder().fit_transform(X['ip'])
# C:\Users\franf\AppData\Local\Temp\ipykernel_25804\3227243978.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['gender'] = LabelEncoder().fit_transform(X['gender'])
# C:\Users\franf\AppData\Local\Temp\ipykernel_25804\3227243978.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['civil_status'] = LabelEncoder().fit_transform(X['civil_status'])
# C:\Users\franf\AppData\Local\Temp\ipykernel_25804\3227243978.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['highest_education_attainment'] = LabelEncoder().fit_transform(X['highest_education_attainment'])
# C:\Users\franf\AppData\Local\Temp\ipykernel_25804\3227243978.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['osy_isy'] = LabelEncoder().fit_transform(X['osy_isy'])
# C:\Users\franf\AppData\Local\Temp\ipykernel_25804\3227243978.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['out'] = LabelEncoder().fit_transform(X['out'])
# C:\Users\franf\AppData\Local\Temp\ipykernel_25804\3227243978.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['youth_with_specific_needs'] = LabelEncoder().fit_transform(X['youth_with_specific_needs'])
# C:\Users\franf\AppData\Local\Temp\ipykernel_25804\3227243978.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['disability'] = LabelEncoder().fit_transform(X['disability'])
# C:\Users\franf\AppData\Local\Temp\ipykernel_25804\3227243978.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['work_status'] = LabelEncoder().fit_transform(X['work_status'])

# %%
# just print 20 sample to check label encoding
X.head(20)
# Out:
#     philhealth_status  ip  gender  age  civil_status  number_of_children  \
# 0                   1   1       0   20             9                   0
# 1                   1   1       1   21             9                   0
# 2                   1   1       1   22             9                   0
# 3                   1   1       1   20             9                   0
# 4                   1   1       1   26             9                   0
# 5                   1   1       1   23             9                   0
# 6                   1   1       0   23             5                   1
# 7                   1   1       1   28             9                   0
# 8                   3   1       0   27             9                   0
# 9                   1   1       0   29             5                   0
# 10                  1   1       1   27             5                   1
# 11                  1   1       0   21             5                   1
# 12                  1   1       0   29             7                   2
# 13                  3   1       0   28             5                   1
# 14                  3   1       1   28             5                   0
# 15                  3   1       0   23             5                   2
# 16                  3   1       1   27             5                   2
# 17                  1   1       0   16             9                   0
# 18                  1   1       1   17             9                   0
# 19                  1   1       0   15             9                   0
#
#     highest_education_attainment  osy_isy  out  youth_with_specific_needs  \
# 0                              5        0    8                          0
# 1                              5        0    8                          0
# 2                             44        0    8                          0
# 3                              5        0    8                          0
# 4                              4        2    8                          0
# 5                              5        0    8                          0
# 6                             17        3    5                          0
# 7                             17        3    5                          0
# 8                             17        3    5                          0
# 9                             17        3    5                          0
# 10                             5        0    8                          0
# 11                             5        0    8                          2
# 12                             5        3    5                          0
# 13                            17        3    5                          0
# 14                            18        3    5                          0
# 15                            17        3    5                          0
# 16                            18        3    5                          0
# 17                            29        0    8                          0
# 18                            40        3    5                          0
# 19                            29        0    8                          0
#
#     disability  work_status
# 0            0            0
# 1            0            2
# 2            0            2
# 3            0            0
# 4            0            2
# 5            0            2
# 6            0            2
# 7            0            0
# 8            0            2
# 9            0            2
# 10           0            2
# 11           0            2
# 12           0            2
# 13           0            2
# 14           0            0
# 15           0            2
# 16           0            2
# 17           0            2
# 18           0            2
# 19           0            2

# %%
# data partitioning
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# gaussian naive bayes
gnb = GaussianNB()

# %%
# model training
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# prediction

y_pred = gnb.predict(X_test)

# %%
# model evaluation

accuracy = accuracy_score(y_test, y_pred)
clf_report = classification_report(y_test, y_pred)
cf = confusion_matrix(y_test,y_pred)

# %%
# result logging
print(f"The accuracy is: {accuracy}")
print(clf_report)
print(cf)
# Out:
# The accuracy is: 0.8379888268156425
#               precision    recall  f1-score   support
#
# NOT PRIORITY       0.82      1.00      0.90       260
#     PRIORITY       0.98      0.42      0.59        98
#
#     accuracy                           0.84       358
#    macro avg       0.90      0.71      0.74       358
# weighted avg       0.86      0.84      0.81       358
#
# [[259   1]
#  [ 57  41]]

# %%
# save model
with open('predict_social_assistance_among_youth_model.pkl', 'wb') as file:
 pickle.dump(gnb, file)

# %%
with open('predict_social_assistance_among_youth_model.pkl', 'rb') as file:
 loaded_knn = pickle.load(file)

# %%
dataset.head()
# Out:
#    no.                      name philhealth_status  ip  gender  age  \
# 0    1             BETE, RHEA M.         DEPENDENT  NO  FEMALE   20
# 1    2  DARUNDAY, CARL KEVEEN G.         DEPENDENT  NO    MALE   21
# 2    3      ABID, DOGENIO JR. A.         DEPENDENT  NO    MALE   22
# 3    4        DARAY, JOHN LOU N.         DEPENDENT  NO    MALE   20
# 4    5           ABID, EUGENE A.         DEPENDENT  NO    MALE   26
#
#   civil_status  number_of_children highest_education_attainment osy_isy   out  \
# 0       SINGLE                   0                COLLEGE LEVEL      IN  NONE
# 1       SINGLE                   0                COLLEGE LEVEL      IN  NONE
# 2       SINGLE                   0                   VOCATIONAL      IN  NONE
# 3       SINGLE                   0                COLLEGE LEVEL      IN  NONE
# 4       SINGLE                   0             COLLEGE GRADUATE    NONE  NONE
#
#   youth_with_specific_needs disability work_status priority_level
# 0                        NO       NONE    EMPLOYED   NOT PRIORITY
# 1                        NO       NONE  UNEMPLOYED   NOT PRIORITY
# 2                        NO       NONE  UNEMPLOYED   NOT PRIORITY
# 3                        NO       NONE    EMPLOYED   NOT PRIORITY
# 4                        NO       NONE  UNEMPLOYED   NOT PRIORITY

# %%
new_instances = X_test

# %%
scale_new_data = scaler.transform(new_instances)
# Out:
# c:\laragon\bin\python\python-3.10\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
predicted_youth_with_priority_assistance = loaded_knn.predict(new_instances)

print(predicted_youth_with_priority_assistance)
# Out:
# ['NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY'
#  'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY'
#  'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY'
#  'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY'
#  'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY'
#  'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY'
#  'PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY'
#  'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY' 'NOT PRIORITY']

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train) 

sample_data = dataset.drop(columns=['priority_level', 'name', 'no.']).head(10)

sample_data['philhealth_status'] = LabelEncoder().fit_transform(sample_data['philhealth_status'])
sample_data['ip'] = LabelEncoder().fit_transform(sample_data['ip'])
sample_data['gender'] = LabelEncoder().fit_transform(sample_data['gender'])
sample_data['civil_status'] = LabelEncoder().fit_transform(sample_data['civil_status'])
sample_data['highest_education_attainment'] = LabelEncoder().fit_transform(sample_data['highest_education_attainment'])
sample_data['osy_isy'] = LabelEncoder().fit_transform(sample_data['osy_isy'])
sample_data['out'] = LabelEncoder().fit_transform(sample_data['out'])
sample_data['youth_with_specific_needs'] = LabelEncoder().fit_transform(sample_data['youth_with_specific_needs'])
sample_data['disability'] = LabelEncoder().fit_transform(sample_data['disability'])
sample_data['work_status'] = LabelEncoder().fit_transform(sample_data['work_status'])

instance = scaler.transform(sample_data)  

sample_predicted_youth_with_priority_assistance = loaded_knn.predict(instance)

sample_predicted_youth_with_priority_assistance
# Out:
# c:\laragon\bin\python\python-3.10\lib\site-packages\sklearn\base.py:458: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# array(['PRIORITY', 'PRIORITY', 'PRIORITY', 'PRIORITY', 'PRIORITY',
#        'PRIORITY', 'PRIORITY', 'PRIORITY', 'PRIORITY', 'PRIORITY'],
#       dtype='<U12')
